# %% [markdown]
# <a href="https://colab.research.google.com/github/TomographicImaging/gVXR-training-dXCT2026/blob/main/notebooks/morning/numpy_integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
#
#  Copyright 2025 United Kingdom Research and Innovation
#  Copyright 2026 United Kingdom Research and Innovation
#
#  Licensed under the Apache License, Version 2.0 (the "License");
#  you may not use this file except in compliance with the License.
#  You may obtain a copy of the License at
#
#      http://www.apache.org/licenses/LICENSE-2.0
#
#  Unless required by applicable law or agreed to in writing, software
#  distributed under the License is distributed on an "AS IS" BASIS,
#  WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  See the License for the specific language governing permissions and
#  limitations under the License.
#
#   Authored by:    Franck Vidal (UKRI-STFC)

# %% [markdown]
# ![gVXR](https://github.com/TomographicImaging/gVXR-Tutorials/blob/main/img/Logo-transparent-small.png?raw=1)
#
# # Numpy integration
#
# This notebook shows how to speed up the simulation by avoiding memory copies when the simulated data must be accessed in Python.
# The table below shows runtimes for the different function calls on my current system.
#
# | Python integration | Array type | Number of images simulated in one second | Speedup |
# |--------------------|------------|------------------------------------------|---------|
# | False | Python | 328 | N/A |
# | False | Numpy | 122 | 0.37 |
# | True | Numpy | 1042 | 3.17 |
#
# If speedup is less than 1, then it is slower than the reference method;
# else if speedup is greater than 1, then it is faster.
#
# <div class="alert alert-block alert-warning">
#     <b>Note:</b> Make sure the Python packages are already installed. See <a href="../README.md">README.md</a> in the root directory of the repository. If you are running this notebook from Google Colab, please run the cell below to install the package with `!pip install gvxr`
# </div>

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # !apt-get install libnvidia-gl-575
    # !pip install gvxr

# %% [markdown]
# # Aims of this session
#
# 1. Revisit the example from last time;
# 2. Estimate the speed up factor when the Numpy integration is used.
#
# ![](https://github.com/TomographicImaging/gVXR-Tutorials/blob/main/img/02-visualisation.png?raw=1)

# %% [markdown]
# ## Import packages
#
# - `os` to create the output directory if needed
# - `numpy` for the NumPy integration
# - `matplotlib` for visually compering images
# - `time` and `datetime` to compute execution durations
# - `gvxr` to simulate X-ray images

# %%
# Import packages
import os # Create the output directory if necessary
import numpy as np # Who does not use Numpy?
from matplotlib import pyplot as plt

import time
from datetime import timedelta

from gvxrPython3 import gvxr # Simulate X-ray images

# %% [markdown]
# ## 1. Recycle the code from [the notebook on First X-ray simulation](notebooks/first_xray_simulation.ipynb)

# %%
# Create an OpenGL context
print("Create an OpenGL context")
gvxr.createOpenGLContext()

# %%
# Create a source
print("Set up the beam")
gvxr.setSourcePosition(-40.0,  0.0, 0.0, "cm")
gvxr.usePointSource()
#  For a parallel source, use gvxr.useParallelBeam()

# %%
# Set its spectrum, here a monochromatic beam
# 1000 photons of 80 keV (i.e. 0.08 MeV) per ray
gvxr.setMonoChromaticPerPixelAtSDD(0.08, "MeV", 1000)
# The following is equivalent: gvxr.setMonoChromaticPerPixelAtSDD(80, "keV", 1000)

# %%
# Set up the detector
print("Set up the detector")
gvxr.setDetectorPosition(10.0, 0.0, 0.0, "cm")
gvxr.setDetectorUpVector(0, 0, -1)
gvxr.setDetectorNumberOfPixels(640, 320)
gvxr.setDetectorPixelSize(0.5, 0.5, "mm")

# %%
# Locate the sample STL file from the package directory
path = os.path.dirname(gvxr.__file__)
fname = path + "/welsh-dragon-small.stl"

# Load the sample data
if not os.path.exists(fname):
    raise IOError(fname)

print("Load the mesh data from", fname)
gvxr.loadMeshFile("Dragon", fname, "mm")

print("Move ", "Dragon", " to the centre")
gvxr.moveToCentre("Dragon")

# %%
# Material properties
print("Set ", "Dragon", "'s material")

# Titanium Aluminum Vanadium Alloy
gvxr.setMixture("Dragon", ["Ti", "Al", "V"], [0.9, 0.06, 0.04])
gvxr.setDensity("Dragon", 4.43, "g.cm-3")

# %% [markdown]
# ## 2. Compute the corresponding X-ray image as a Python array without the Numpy integration
#
# We run it 250 times to gather statistically meaningful results.

# %%
# Compute an X-ray image
# We convert the array in a Numpy structure and store the data using single-precision floating-point numbers.

number_of_iterations = 500
print("Compute an X-ray image", number_of_iterations, "times")

without_numpy_integration1_start_time = time.monotonic()
for i in range(number_of_iterations):
    x_ray_image1 = gvxr.computeXRayImage()
without_numpy_integration1_end_time = time.monotonic()

# %% [markdown]
# ## 3. Compute the corresponding X-ray image as a Numpy array without the Numpy integration
#
# We run it 250 times to gather statistically meaningful results.

# %%
# Compute an X-ray image
# We convert the array in a Numpy structure and store the data using single-precision floating-point numbers.

print("Compute an X-ray image", number_of_iterations, "times")

without_numpy_integration2_start_time = time.monotonic()
for i in range(number_of_iterations):
    x_ray_image2 = np.array(gvxr.computeXRayImage(), dtype=np.single)
without_numpy_integration2_end_time = time.monotonic()

# %% [markdown]
# ## 4. Compute the corresponding X-ray image as a Numpy array with the Numpy integration
#
# We run it 250 times to gather statistically meaningful results.

# %%
# Compute an X-ray image
# We convert the array in a Numpy structure and store the data using single-precision floating-point numbers.

print("Compute an X-ray image", number_of_iterations, "times")

with_numpy_integration_start_time = time.monotonic()
x_ray_image3 = np.zeros((gvxr.getDetectorNumberOfPixels()[1], gvxr.getDetectorNumberOfPixels()[0]), dtype=np.single)
for i in range(number_of_iterations):
    gvxr.computeXRayImage(x_ray_image3)
with_numpy_integration_end_time = time.monotonic()

# %% [markdown]
# ## 5. Make sure the images are identical

# %%
print("min values:    %.4f,\t%.4f,\t%.4f" % (np.min(x_ray_image1), np.min(x_ray_image2), np.min(x_ray_image3)))
print("max values:    %.4f,\t%.4f,\t%.4f" % (np.max(x_ray_image1), np.max(x_ray_image2), np.max(x_ray_image3)))
print("mean values:   %.4f,\t%.4f,\t%.4f" % (np.mean(x_ray_image1), np.mean(x_ray_image2), np.mean(x_ray_image3)))
print("median values: %.4f,\t%.4f,\t%.4f" % (np.median(x_ray_image1), np.median(x_ray_image2), np.median(x_ray_image3)))
print("std dev:       %.4f,\t%.4f,\t%.4f" % (np.std(x_ray_image1), np.std(x_ray_image2), np.std(x_ray_image3)))

# %%
fig, axs = plt.subplots(1,3, figsize=(15,10))

axs[0].set_title("Python array without the Numpy integration")
axs[1].set_title("Numpy array without the Numpy integration")
axs[2].set_title("Numpy array with the Numpy integration")

axs[0].imshow(-np.log(x_ray_image1), cmap="gray")
axs[1].imshow(-np.log(x_ray_image2), cmap="gray")
axs[2].imshow(-np.log(x_ray_image3), cmap="gray")

# %% [markdown]
# ## 6. Compare the performances

# %%
duration_without_numpy_integration1 = timedelta(seconds=without_numpy_integration1_end_time -
                                                        without_numpy_integration1_start_time).total_seconds()

duration_without_numpy_integration2 = timedelta(seconds=without_numpy_integration2_end_time -
                                                        without_numpy_integration2_start_time).total_seconds()

duration_with_numpy_integration = timedelta(seconds=with_numpy_integration_end_time -
                                                    with_numpy_integration_start_time).total_seconds()

# %% [markdown]
# ---
# ## Task:
#
# Uncomment the cell below and complete the code to compute the speedup factor for the:
# - conversion of a Python array into a NumPy array, i.e. no NumPy integration;
# - NumPy integration.
#
# To compute a speedup, use:
#
# $$speedup = \frac{old~duration}{new~duration}$$
#
# If speedup is less than 1, then it is slower than the reference method;
# else if speedup is greater than 1, then it is faster.
#
# Can you explain the results?

# %%
# speedup_without_numpy_integration =
# speedup_with_numpy_integration =

# %%
# %load 'snippets/numpy_integration-01.py'

# %%
print("Python array without Numpy integration: %i, images per second, speedup: N/A" %
      round(number_of_iterations / duration_without_numpy_integration1))

print("Numpy array without Numpy integration: %i images per second, speedup: %.2f" %
      (round(number_of_iterations / duration_without_numpy_integration2), speedup_without_numpy_integration))

print("Numpy array with Numpy integration: %i images per second, speedup: %.2f" %
      (round(number_of_iterations / duration_with_numpy_integration), speedup_with_numpy_integration))

# %% [markdown]
# # Cleaning up
#
# Once we have finished, it is good practice to clean up the OpenGL contexts and windows with the following command. Note that due to the object-oriented programming nature of the core API of gVXR, this step is automatic anyway.

# %%
gvxr.destroy()
